# %% [markdown]
# # Running data

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
running_2018 = pd.read_csv('Data/2018-running.csv', index_col='날짜')
running_2019 = pd.read_csv('Data/2019-running.csv', index_col='날짜')
running_2020 = pd.read_csv('Data/2020-running.csv', index_col='날짜')
running_2021 = pd.read_csv('Data/2021-running.csv', index_col='날짜')

# %%
dataframes = [running_2018, running_2019, running_2020, running_2021]
running_df = pd.concat(dataframes)

# %% [markdown]
# # Graph 그리기

# %%
mpl.rc('font', family='AppleGothic')

# %%
running_graph_2018 = running_2018['거리'].plot(kind='line', 
                                             title='2018 running distance', 
                                             figsize=(20, 4), 
                                             legend=False, 
                                             fontsize=8, 
                                             color='orange') # Orange, Running Level 2
running_graph_2018.set_xlabel('날짜', fontsize=12)
running_graph_2018.set_ylabel('거리', fontsize=12)
plt.show()

# %%
# running_graph_2018.dropna(inplace=True)
running_2018.plot(
              kind='scatter',
              x='거리',
              y='칼로리',
              color='orange',
              alpha=0.3,
              title='2018 running 거리 및 칼로리 상관관계'
              )
plt.show()

# %%
running_graph_2019 = running_2019['거리'].plot(kind='line', 
                                             title='2019 running distance', 
                                             figsize=(20, 4), 
                                             legend=False, 
                                             fontsize=9, 
                                             color='springgreen') # Green, Running Level 3
running_graph_2019.set_xlabel('날짜', fontsize=12)
running_graph_2019.set_ylabel('거리', fontsize=12)
plt.show()

# %%
running_2019.plot(
              kind='scatter',
              x='거리',
              y='칼로리',
              color='springgreen',
              alpha=0.3,
              title='2019 running 거리 및 칼로리 상관관계'
              )
plt.show()

# %%
running_graph_2020 = running_2020['거리'].plot(kind='line', 
                                             title='2020 running distance', 
                                             figsize=(20, 5), 
                                             legend=False, 
                                             fontsize=9, 
                                             color='springgreen')
running_graph_2020.set_xlabel('날짜', fontsize=12)
running_graph_2020.set_ylabel('거리', fontsize=12)
plt.show()

# %%
running_2020.plot(
              kind='scatter',
              x='거리',
              y='칼로리',
              color='springgreen',
              alpha=0.3,
              title='2020 running 거리 및 칼로리 상관관계'
              )
plt.show()

# %%
running_graph_2021 = running_2021['거리'].plot(kind='line', 
                                             title='2021 running distance', 
                                             figsize=(20, 5), 
                                             legend=False, 
                                             fontsize=9, 
                                             color='deepskyblue')
running_graph_2021.set_xlabel('날짜', fontsize=12)
running_graph_2021.set_ylabel('거리', fontsize=12)
plt.show()

# %%
running_2021.plot(
              kind='scatter',
              x='거리',
              y='칼로리',
              color='deepskyblue',
              alpha=0.3,
              title='2020 running 거리 및 칼로리 상관관계'
              )
plt.show()

# %%
running_graph = running_df['거리'].plot(kind='line', 
                                             title='total running distance', 
                                             figsize=(20, 4), 
                                             legend=False, 
                                             fontsize=9, 
                                             color='gray') # Blue, Running Level 4
running_graph.set_xlabel('날짜', fontsize=12)
running_graph.set_ylabel('거리', fontsize=12)
plt.show()

# %%
running_df.plot(
              kind='scatter',
              x='거리',
              y='칼로리',
              color='gray',
              alpha=0.3,
              title='running 거리 및 칼로리 상관관계' # Navy, running total
              )
plt.show()
